# %% [markdown]
# <a href="https://colab.research.google.com/github/anveshveeramalla/Anvesh_INFO5731_SPRING2022/blob/main/INFO5731_Assignment_Two_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [Apple iPhone 11](https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/dp/B07ZPKF8RG/ref=sr_1_13?dchild=1&keywords=iphone+12&qid=1631721363&sr=8-13) on amazon.
#
# (2) Collect the top 10000 User Reviews of the film [Shang-Chi and the Legend of the Ten Rings](https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3) from IMDB.
#
# (3) Collect all the reviews of the top 100 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 tweets by using hashtag ["#blacklivesmatter"](https://twitter.com/hashtag/blacklivesmatter) from Twitter.

# %%
# Write your code here
import pandas as pd
import tweepy as tp
import pandas as pd
import csv
import re 
import string


key_consumer= '2Em7SxlX9jPMfL4x97r3zMO0x'
secret_consumer= 'sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd'
key_access= '1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT'
access_secret= 'oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF'

auth = tp.OAuthHandler(key_consumer, secret_consumer)
auth.set_access_token(key_access, access_secret)

api = tp.API(auth,wait_on_rate_limit=True)
 
csvFile = open('data_twitter', 'a')
csvWriter = csv.writer(csvFile)
date_since = "2021-12-01"
words_search = "#BlackLivesMatter"      # enter your words
new_search = words_search + " -filter:retweets"

tweets=tp.Cursor(api.search,q=new_search,count=100,
                           lang="en",
                           since=date_since).items(10000)
csvWriter.writerow(["Date","Tweet","User","Location"])                      
for tweet in tweets:  
  csvWriter.writerow([tweet.created_at, tweet.text,tweet.user.screen_name, tweet.user.location])
  
df=pd.read_csv('data_twitter')
df.head(10000)
# Out:
#                      Date  ...                       Location
# 0     2022-02-28 02:48:57  ...                    Clifton, NJ
# 1     2022-02-28 02:48:43  ...                            NaN
# 2     2022-02-28 02:48:06  ...                  Cell block 22
# 3     2022-02-28 02:47:39  ...                       brooklyn
# 4     2022-02-28 02:47:07  ...                 #GlobalCitizen
# ...                   ...  ...                            ...
# 9944  2022-02-21 08:48:11  ...                Kaduna Nigeria
# 9945  2022-02-21 08:46:19  ...  Tazlina SW Subdivision ALASKA
# 9946  2022-02-21 08:45:31  ...                            NaN
# 9947  2022-02-21 08:43:05  ...                 United Kingdom
# 9948  2022-02-21 08:39:33  ...                         Canada
#
# [9949 rows x 4 columns]

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write your code here

# Write your code here
df['Cleaned Text']=''
df.head(5)
# Out:
#                   Date  ... Cleaned Text
# 0  2022-02-28 02:48:57  ...
# 1  2022-02-28 02:48:43  ...
# 2  2022-02-28 02:48:06  ...
# 3  2022-02-28 02:47:39  ...
# 4  2022-02-28 02:47:07  ...
#
# [5 rows x 5 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
lemmatizer=WordNetLemmatizer()
stop_words=set(stopwords.words('english'))
ps = PorterStemmer()


for i in df.index:
  k=word_tokenize(df['Tweet'][i])
  l=[word.lower() for word in k if word.isalpha() and word not in stop_words]
  
  lema=[lemmatizer.lemmatize(words) for words in l]
  stemm=[ps.stem(words) for words in lema]
  clean_text=' '.join(stemm)
  df['Cleaned Text'][i]=clean_text
  
 
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
#                   Date  ...                                       Cleaned Text
# 0  2022-02-28 02:48:57  ...  when jennienguyenluv said everyon capabl i hop...
# 1  2022-02-28 02:48:43  ...  sunday elden ring we are live http blacklivesm...
# 2  2022-02-28 02:48:06  ...  audio can black life matter too mprisondpoetz ...
# 3  2022-02-28 02:47:39  ...  black peopl could ever consid racist if live b...
# 4  2022-02-28 02:47:07  ...  how white woman invest slaveri shape america t...
#
# [5 rows x 5 columns]

# %%
df.to_csv('clean_data_twitter.csv')

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Write your code here
# Write your code here
df=pd.read_csv('clean_data_twitter.csv')
df['Count of POS']=''
df.head()
# Out:
#    Unnamed: 0  ... Count of POS
# 0           0  ...
# 1           1  ...
# 2           2  ...
# 3           3  ...
# 4           4  ...
#
# [5 rows x 7 columns]

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('universal_tagset')
from collections import Counter
for i in df.index:
  k=word_tokenize(df['Cleaned Text'][i])
  tags=nltk.pos_tag(k)
  counts = Counter( tag for word,  tag in tags)
  
  d=dict(counts)
  l=[]
  for key in d:
    
    temp=''
    if key=='NN':
      temp=temp+'Nouns - '+str(d.get(key))
      
    if key=='VB':
      temp=temp+'Verbs - '+str(d.get(key))
      
    if key=='JJ':
      temp=temp+'Ajective - '+str(d.get(key))
      
    if key=='RB':
      temp=temp+'Adverb - '+str(d.get(key))
    l.append(temp)
    count_text=','.join(l)
    df['Count of POS'][i]=count_text
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.to_csv('tagged_data.csv')
df.head(100)
# Out:
#     Unnamed: 0  ...                                    Count of POS
# 0            0  ...                       ,Nouns - 5,,Ajective - 2,
# 1            1  ...                        Ajective - 3,Nouns - 4,,
# 2            2  ...              Nouns - 8,,Ajective - 2,Adverb - 1
# 3            3  ...  Ajective - 2,Nouns - 4,,Adverb - 1,Verbs - 1,,
# 4            4  ...              ,Ajective - 1,Nouns - 6,Verbs - 1,
# ..         ...  ...                                             ...
# 95          95  ...             Nouns - 6,,,,Verbs - 1,Ajective - 1
# 96          96  ...                          Ajective - 1,Nouns - 8
# 97          97  ...   ,Adverb - 1,,Verbs - 1,Ajective - 1,Nouns - 4
# 98          98  ...           Adverb - 2,Ajective - 4,,,Nouns - 4,,
# 99          99  ...                          Nouns - 6,Ajective - 1
#
# [100 rows x 7 columns]

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
from spacy import displacy
for i in range(30):
  displacy.render(nlp(df['Cleaned Text'][i]),jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f9b8d0aefa14491ca6caceaaec5e7d0c-0" class="displacy" width="1800" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">jennienguyenluv</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 46.0 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 40.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.2 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)

k=df['Tweet'][348]
print(k)
ner_results = nlp(k)
print(ner_results)
# Out:
# Downloading:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/829 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/413M [00:00<?, ?B/s]
# My Hearts♥️Are Prayers🙏🏾 With #AfricansinUkraine .. This Ridiculous On What’s is Happening With Our Brothers &amp; Sist… https://t.co/j3QTtlL20k
# [{'entity': 'B-MISC', 'score': 0.9145514, 'index': 6, 'word': 'Africans', 'start': 31, 'end': 39}, {'entity': 'B-ORG', 'score': 0.5743378, 'index': 33, 'word': 'Si', 'start': 115, 'end': 117}]

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# The constituency parse tree is based on the formalism of context-free grammars. In this type of tree, the sentence is divided into constituents, that is, sub-phrases that belong to a specific category in the grammar.
# As opposed to constituency parsing, dependency parsing doesn’t make use of phrasal constituents or sub-phrases. Instead, the syntax of the sentence is expressed in terms of dependencies between words — that is, directed, typed edges between words in a graph.
